# %% [markdown]
# ### COVID-19 Deaths

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC  
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
covid = pd.read_csv("covid-states.csv")
covid.head()
# Out:
#          date state dataQualityGrade   death  deathConfirmed  deathIncrease  \
# 0  2020-12-02    AK                A   122.0           122.0              0
# 1  2020-12-02    AL                A  3711.0          3326.0             73
# 2  2020-12-02    AR               A+  2522.0          2312.0             10
# 3  2020-12-02    AS                D     0.0             NaN              0
# 4  2020-12-02    AZ               A+  6739.0          6237.0             52
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            NaN         768.0                   768.0                  164.0
# 1          385.0       25821.0                 25821.0                 1801.0
# 2          210.0        9110.0                  9110.0                 1088.0
# 3            NaN           NaN                     NaN                    NaN
# 4          502.0       26312.0                 26312.0                 2699.0
#
#    ...  totalTestResults  totalTestResultsIncrease  totalTestsAntibody  \
# 0  ...         1024643.0                      6015                 NaN
# 1  ...         1603523.0                      9681                 NaN
# 2  ...         1703266.0                     11813                 NaN
# 3  ...            1988.0                         0                 NaN
# 4  ...         2288204.0                     16290            365871.0
#
#    totalTestsAntigen  totalTestsPeopleAntibody  totalTestsPeopleAntigen  \
# 0                NaN                       NaN                      NaN
# 1                NaN                   73187.0                      NaN
# 2            21856.0                       NaN                 144866.0
# 3                NaN                       NaN                      NaN
# 4                NaN                       NaN                      NaN
#
#    totalTestsPeopleViral  totalTestsPeopleViralIncrease  totalTestsViral  \
# 0                    NaN                              0        1024643.0
# 1              1603523.0                           9681              NaN
# 2                    NaN                              0        1703266.0
# 3                    NaN                              0           1988.0
# 4              2288204.0                          16290              NaN
#
#    totalTestsViralIncrease
# 0                     6015
# 1                        0
# 2                    11813
# 3                        0
# 4                        0
#
# [5 rows x 42 columns]

# %%
print("Size/Shape of the dataset",covid.shape)
print("Checking for null values:\n",covid.isnull().sum())
print("Checking Data-type:",covid.dtypes)
# Out:
# Size/Shape of the dataset (15409, 42)
# Checking for null values:
#  date                                    0
# state                                   0
# dataQualityGrade                     1261
# death                                 826
# deathConfirmed                       8691
# deathIncrease                           0
# deathProbable                       10413
# hospitalized                         6127
# hospitalizedCumulative               6127
# hospitalizedCurrently                3105
# hospitalizedIncrease                    0
# inIcuCumulative                     12757
# inIcuCurrently                       7939
# negative                              308
# negativeIncrease                        0
# negativeTestsAntibody               14438
# negativeTestsPeopleAntibody         14657
# negativeTestsViral                  12154
# onVentilatorCumulative              14496
# onVentilatorCurrently                9326
# positive                              150
# positiveCasesViral                   3509
# positiveIncrease                        0
# positiveScore                           0
# positiveTestsAntibody               13239
# positiveTestsAntigen                14710
# positiveTestsPeopleAntibody         14630
# positiveTestsPeopleAntigen          15018
# positiveTestsViral                  10481
# recovered                            4490
# totalTestEncountersViral            11783
# totalTestEncountersViralIncrease        0
# totalTestResults                       35
# totalTestResultsIncrease                0
# totalTestsAntibody                  12456
# totalTestsAntigen                   14292
# totalTestsPeopleAntibody            14179
# totalTestsPeopleAntigen             14885
# totalTestsPeopleViral                8892
# totalTestsPeopleViralIncrease           0
# totalTestsViral                      5756
# totalTestsViralIncrease                 0
# dtype: int64
# Checking Data-type: date                                 object
# state                                object
# dataQualityGrade                     object
# death                               float64
# deathConfirmed                      float64
# deathIncrease                         int64
# deathProbable                       float64
# hospitalized                        float64
# hospitalizedCumulative              float64
# hospitalizedCurrently               float64
# hospitalizedIncrease                  int64
# inIcuCumulative                     float64
# inIcuCurrently                      float64
# negative                            float64
# negativeIncrease                      int64
# negativeTestsAntibody               float64
# negativeTestsPeopleAntibody         float64
# negativeTestsViral                  float64
# onVentilatorCumulative              float64
# onVentilatorCurrently               float64
# positive                            float64
# positiveCasesViral                  float64
# positiveIncrease                      int64
# positiveScore                         int64
# positiveTestsAntibody               float64
# positiveTestsAntigen                float64
# positiveTestsPeopleAntibody         float64
# positiveTestsPeopleAntigen          float64
# positiveTestsViral                  float64
# recovered                           float64
# totalTestEncountersViral            float64
# totalTestEncountersViralIncrease      int64
# totalTestResults                    float64
# totalTestResultsIncrease              int64
# totalTestsAntibody                  float64
# totalTestsAntigen                   float64
# totalTestsPeopleAntibody            float64
# totalTestsPeopleAntigen             float64
# totalTestsPeopleViral               float64
# totalTestsPeopleViralIncrease         int64
# totalTestsViral                     float64
# totalTestsViralIncrease               int64
# dtype: object

# %%
#Dropping the column SNO
covid.drop(["dataQualityGrade"],1,inplace = True)

# %%
#Data Analysis for Washington DC
dc_data = covid[covid["state"]=="DC"]
dc_data.head()
# Out:
#            date state  death  deathConfirmed  deathIncrease  deathProbable  \
# 8    2020-12-02    DC  690.0             NaN              5            NaN
# 64   2020-12-01    DC  685.0             NaN              5            NaN
# 120  2020-11-30    DC  680.0             NaN              0            NaN
# 176  2020-11-29    DC  680.0             NaN              2            NaN
# 232  2020-11-28    DC  678.0             NaN              1            NaN
#
#      hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 8             NaN                     NaN                  165.0
# 64            NaN                     NaN                  160.0
# 120           NaN                     NaN                  158.0
# 176           NaN                     NaN                  145.0
# 232           NaN                     NaN                  157.0
#
#      hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# 8                       0  ...          701485.0                      4076
# 64                      0  ...          697409.0                      2153
# 120                     0  ...          695256.0                      4914
# 176                     0  ...          690342.0                      5004
# 232                     0  ...          685338.0                     12899
#
#      totalTestsAntibody  totalTestsAntigen  totalTestsPeopleAntibody  \
# 8                   NaN                NaN                       NaN
# 64                  NaN                NaN                       NaN
# 120                 NaN                NaN                       NaN
# 176                 NaN                NaN                       NaN
# 232                 NaN                NaN                       NaN
#
#      totalTestsPeopleAntigen  totalTestsPeopleViral  \
# 8                        NaN               308164.0
# 64                       NaN               307336.0
# 120                      NaN               306447.0
# 176                      NaN               305563.0
# 232                      NaN               304033.0
#
#      totalTestsPeopleViralIncrease  totalTestsViral  totalTestsViralIncrease
# 8                              828              NaN                        0
# 64                             889              NaN                        0
# 120                            884              NaN                        0
# 176                           1530              NaN                        0
# 232                           4071              NaN                        0
#
# [5 rows x 41 columns]

# %%
dc_data = dc_data.fillna(0)
dc_data.head()
# Out:
#            date state  death  deathConfirmed  deathIncrease  deathProbable  \
# 8    2020-12-02    DC  690.0             0.0              5            0.0
# 64   2020-12-01    DC  685.0             0.0              5            0.0
# 120  2020-11-30    DC  680.0             0.0              0            0.0
# 176  2020-11-29    DC  680.0             0.0              2            0.0
# 232  2020-11-28    DC  678.0             0.0              1            0.0
#
#      hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 8             0.0                     0.0                  165.0
# 64            0.0                     0.0                  160.0
# 120           0.0                     0.0                  158.0
# 176           0.0                     0.0                  145.0
# 232           0.0                     0.0                  157.0
#
#      hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# 8                       0  ...          701485.0                      4076
# 64                      0  ...          697409.0                      2153
# 120                     0  ...          695256.0                      4914
# 176                     0  ...          690342.0                      5004
# 232                     0  ...          685338.0                     12899
#
#      totalTestsAntibody  totalTestsAntigen  totalTestsPeopleAntibody  \
# 8                   0.0                0.0                       0.0
# 64                  0.0                0.0                       0.0
# 120                 0.0                0.0                       0.0
# 176                 0.0                0.0                       0.0
# 232                 0.0                0.0                       0.0
#
#      totalTestsPeopleAntigen  totalTestsPeopleViral  \
# 8                        0.0               308164.0
# 64                       0.0               307336.0
# 120                      0.0               306447.0
# 176                      0.0               305563.0
# 232                      0.0               304033.0
#
#      totalTestsPeopleViralIncrease  totalTestsViral  totalTestsViralIncrease
# 8                              828              0.0                        0
# 64                             889              0.0                        0
# 120                            884              0.0                        0
# 176                           1530              0.0                        0
# 232                           4071              0.0                        0
#
# [5 rows x 41 columns]

# %%
dc_data.set_index('date', inplace =True)

# %%
# Specified data columns
X = dc_data[['hospitalized','onVentilatorCurrently','positive',\
             'positiveCasesViral','positiveTestsAntibody', 'positiveTestsAntigen','positiveTestsPeopleAntibody',\
             'positiveTestsPeopleAntigen','positiveTestsViral','totalTestEncountersViral',\
             'totalTestEncountersViralIncrease','totalTestResults','totalTestResultsIncrease',\
             'totalTestsAntibody', 'totalTestsAntigen','totalTestsPeopleAntibody','totalTestsPeopleAntigen',\
             'totalTestsPeopleViral','totalTestsPeopleViralIncrease','totalTestsViral']]
y = dc_data['death']

# %%
len(dc_data.columns)
# Out:
# 40

# %% [markdown]
# ### Model 1 - SVC

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = SVC()
model
# Out:
# SVC()

# %%
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.14215686274509803
# Testing Data Score: 0.13043478260869565

# %% [markdown]
# #### Low Scores -  different model required for training and testing data

# %% [markdown]
# ## Model 2 - LinearRegression

# %%
# Specified data columns
X = dc_data[['hospitalized','onVentilatorCurrently','positive',\
             'positiveCasesViral','positiveTestsAntibody', 'positiveTestsAntigen','positiveTestsPeopleAntibody',\
             'positiveTestsPeopleAntigen','positiveTestsViral','totalTestEncountersViral',\
             'totalTestEncountersViralIncrease','totalTestResults','totalTestResultsIncrease',\
             'totalTestsAntibody', 'totalTestsAntigen','totalTestsPeopleAntibody','totalTestsPeopleAntigen',\
             'totalTestsPeopleViral','totalTestsPeopleViralIncrease','totalTestsViral']]
y = dc_data['death']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9948860479279095
# Testing Data Score: 0.9953102789598155
